# %%
import os
os.environ['PYTHONHASHSEED']=str(0)
import random
random.seed(0)
import numpy as np
np.random.seed(0)
import tensorflow as tf
tf.set_random_seed(0)



import pandas as pd
import matplotlib.pyplot as plt
import pickle
import itertools
import time
import itertools
from IPython.display import display, clear_output


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
x = np.linspace(0,10, 50)
y = np.logspace(-2, 4, 60)

xx, yy = np.meshgrid(x, y)
zz = xx**2 + np.log(yy)*10
plt.contourf(xx, yy, zz, 200)
plt.yscale('log')

# %%
x = np.random.uniform(2,10, size=(460))
y = np.random.uniform(1, 11, size=(460))
z = np.sin(x*y/10)

# %%
plt.tricontourf(x, y, z)
