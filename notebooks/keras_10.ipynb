# %%
import os, sys
os.environ['PYTHONHASHSEED']=str(0)
import random
random.seed(0)
import numpy as np
np.random.seed(0)
import tensorflow as tf
tf.set_random_seed(0)

# ## uncomment for reproducibility ##
# from keras import backend as K
# session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
# sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
# K.set_session(sess)

import pandas as pd
import matplotlib.pyplot as plt
import pickle
import itertools
import time
import itertools
from IPython.display import display, clear_output

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import SimpleRNN
from keras.initializers import glorot_uniform

from keras.optimizers import Adam
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.callbacks import Callback

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
VERSION = '10'

try:
    import google.colab
    from google.colab import drive

    drive.mount('/content/gdrive')
    root_path = 'gdrive/My Drive/Colab Notebooks/deep_mouse/'
    print('Working on google colab')
except:
    root_path = '../'
    print('Working locally')

directory= f'{root_path}models/{VERSION}'
if not os.path.exists(directory):
    os.makedirs(directory)    
    
sys.path.append(f'{root_path}/rsc/{VERSION}') # Adds pyLi directory to python modules path.
from load_data import load_data
from pre_process_data import pre_process_data
from create_model import create_model
from helper import play_bell, LossHistory, add_grid_and_save
from train_model import train_model
from run_training import run_training
from parameter_space import Parameter_space
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Working on google colab

# %% [markdown]
# ## Hyperparameters setting

# %%
def create_grid(params={}):
    
    grid_file_path = '{}/model_data/grid_{}.pkl'.format(root_path, VERSION)
    
    if os.path.isfile(grid_file_path):
        grid_df = pd.read_pickle(grid_file_path)
        test_index = grid_df['test_index'].max() + 1
    else:
        test_index = 0

    current_grid = {
        'version'                : ['str'     , VERSION],
        'params'                 : ['O'       , params],
        'test_index'             : [np.int    , test_index],
        'root_path'              : ['str'     , root_path],
        'GPU'                    : [np.int    , 1],
        
        # Load and preprocess
        'batch_size_data'        : [np.int    , 200],
        'x_std'                  : [np.float  , 3.398],
        'y_std'                  : [np.float  , 2.926],
        'sigma_cut'              : [np.float  , 0.1],
        'training_size'          : [np.int    , 200],
        
        # Metrics
        'dropout'                 : [np.float  , 0.],
        'best_model_metric'      : ['str'     , 'val_acc'],
        'training_metric'        : ['str'     , 'accuracy'],
        
        # Random seeds
        'seed_skf'               : [np.int    , 0],
        'seed_numpy'             : [np.int    , 0],
        'seed_tensorflow'        : [np.int    , 0],
        'seed_random'            : [np.int    , 0],
        'seed_sklearn'           : [np.int    , 0],
        'seed_model'             : [np.int    , 0],
        
        # Model properties
        'input_shape'            : ['O'       , None],
        'GRU_size'               : [np.int    , 200],
        'dropout'                : [np.float  , 0],
        'conv_layers'            : [np.int    , 1],
        
        # Training parameters
        'learning_rate'          : [np.float  , 1.3e-4],
        'batch_size'             : [np.int    , 32],
        'epochs'                 : [np.int    , 200],
        'test_size'              : [np.float  , 0.15],
        'skf_n_splits'           : [np.int    , 5],
        
        # Outputs
        'best_model_paths'       : ['O'       , []],
        'best_model_accuracies'  : ['O'       , []],
        'fit_outs'               : ['O'       , []]}

    for key, value in params.items():
        current_grid[key][1] = value
    return current_grid

# %% [markdown]
# ### Run training

# %%
grid = create_grid()

X_train, X_test, y_train, y_test = load_data(grid)
X_train, y_train = pre_process_data(X_train, y_train, grid)
X_test, y_test = pre_process_data(X_test, y_test, grid)

# %%
import time
def test_params(next_point_to_probe):
    with open (f'{root_path}log.txt', 'a') as f:
        f.write(f'{time.ctime()}  -  starting {next_point_to_probe}\n')
    print(f'Testing {next_point_to_probe}')
    grid = create_grid(next_point_to_probe)
    grid = run_training(X_train, y_train, grid, verbose=True)
    
    val_acc_history = [fit_out.history['val_acc'] for fit_out in grid['fit_outs'][1]]
    val_accuracy_estimator = np.mean(val_acc_history, 0)[130:180].mean()
    with open (f'{root_path}log.txt', 'a') as f:
        f.write(f'{time.ctime()}  -  finished {next_point_to_probe}\n')
    
    return val_accuracy_estimator

# %%
# %%time


ps = Parameter_space(bounds={
    'GRU_size' : (20, 200, 'int'),
    'conv_layers' : (0, 3, 'int')
})

# ps.bayesopt(test_params, kappa=0.25)


# # ## BAYESIAN SEARCH
# grid_file_path = '{}/model_data/grid_{}.pkl'.format(root_path, VERSION)
# if os.path.isfile(grid_file_path):
#     grid_df = pd.read_pickle(grid_file_path)


#     for fo, param in zip(grid_df.fit_outs, grid_df.params):
#         somma = [x.history['val_acc'] for x in fo]    
#         s = np.mean(somma, 0)[130:180].mean()
#         ps.register_point(param, s)

for _ in range(20):
    next_point_to_probe = ps.get_random_next(time_seed=True)
    target = test_params(next_point_to_probe)
#     ps.register_point(point=next_point_to_probe, target=target)
# Out:
# Testing {'GRU_size': 181, 'conv_layers': 1}
#
# CV validation 1 of 5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# [####################] acc: 0.844 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 01 min, 55 sec
# Testing {'GRU_size': 95, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 01 min, 29 sec
# Testing {'GRU_size': 159, 'conv_layers': 3}
#
# CV validation 1 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 01 min, 36 sec
# Testing {'GRU_size': 84, 'conv_layers': 0}
#
# CV validation 1 of 5
# [####################] acc: 0.844 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.812 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 23 sec
# Testing {'GRU_size': 126, 'conv_layers': 0}
#
# CV validation 1 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.844 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.844 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 49 sec
# Testing {'GRU_size': 163, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 00 sec
# Testing {'GRU_size': 123, 'conv_layers': 1}
#
# CV validation 1 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 19 sec
# Testing {'GRU_size': 172, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 17 sec
# Testing {'GRU_size': 140, 'conv_layers': 3}
#
# CV validation 1 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 24 sec
# Testing {'GRU_size': 66, 'conv_layers': 3}
#
# CV validation 1 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 35 sec
# Testing {'GRU_size': 153, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 02 min, 45 sec
# Testing {'GRU_size': 116, 'conv_layers': 0}
#
# CV validation 1 of 5
# [####################] acc: 0.812 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.812 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.750 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 39 sec
# Testing {'GRU_size': 190, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 02 sec
# Testing {'GRU_size': 143, 'conv_layers': 1}
#
# CV validation 1 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.812 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 20 sec
# Testing {'GRU_size': 64, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 13 sec
# Testing {'GRU_size': 92, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 1.000 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 25 sec
# Testing {'GRU_size': 141, 'conv_layers': 1}
#
# CV validation 1 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.938 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 45 sec
# Testing {'GRU_size': 158, 'conv_layers': 2}
#
# CV validation 1 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.969 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 46 sec
# Testing {'GRU_size': 78, 'conv_layers': 1}
#
# CV validation 1 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.875 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.844 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 03 min, 57 sec
# Testing {'GRU_size': 38, 'conv_layers': 1}
#
# CV validation 1 of 5
# [####################] acc: 0.812 eta: 00 hours, 00 min, 00 sec
# CV validation 2 of 5
# [####################] acc: 0.844 eta: 00 hours, 00 min, 00 sec
# CV validation 3 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 4 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec
# CV validation 5 of 5
# [####################] acc: 0.906 eta: 00 hours, 00 min, 00 sec  --  Model trained in 00 hours, 04 min, 05 sec

# %%
drive_path = '{}model_data/grid_{}.pkl'.format(root_path, VERSION)
df = pd.read_pickle(drive_path)

df = df[df.best_model_accuracies.apply(lambda x:len(x))==5].reset_index()

xyz = np.ones([4, df.shape[0]])

for index, (gru_size, conv_layers, fits_outs) in df[['GRU_size', 'conv_layers', 'fit_outs']].iterrows():
    somma = [x.history['val_acc'] for x in fits_outs]    
    s = np.mean(somma, 0)[170:190].mean()
    sigma = np.mean(somma, 0)[170:190].std()

    xyz[0, index] = gru_size
    xyz[1, index] = conv_layers
    xyz[2, index] = s
    xyz[3, index] = sigma


fig, ax = plt.subplots(1, figsize=(5, 3))
scatterplot = plt.scatter(xyz[0,:], xyz[1,:], c=xyz[2,:], s=1/(xyz[2,:])*2e2, zorder=10, marker='h', edgecolors='black')
ax.tricontourf(xyz[0,:], xyz[1,:], xyz[2,:], alpha=0.2, zorder=3)
plt.colorbar(scatterplot, label='validation accuracy')
ax.set(**{'xlabel':'GRU size', 'ylabel':'conv layers'});

# %%
fig, ax = plt.subplots(int(np.ceil(df.shape[0]/4)),4, figsize=(15, 19))


for index, (gru_size, n_layers, fo) in df[['GRU_size', 'conv_layers', 'fit_outs']].iterrows():

    column = index%4
    row = int(index/4)


    somma = [x.history['val_acc'] for x in fo]
    line, = ax[row, column].plot(np.mean(somma, 0), label='validation accuracy')
    ax[row, column].fill_between(range(np.mean(somma, 0).shape[0]),np.mean(somma, 0)-np.std(somma, 0), np.mean(somma, 0)+np.std(somma, 0),
                    color=line.get_color(), alpha=0.3)
    
    somma = [x.history['acc'] for x in fo]
    line, = ax[row, column].plot(np.mean(somma, 0), label='accuracy')
    ax[row, column].fill_between(range(np.mean(somma, 0).shape[0]),np.mean(somma, 0)-np.std(somma, 0), np.mean(somma, 0)+np.std(somma, 0),
                    color=line.get_color(), alpha=0.3)
    ax[row, column].set_title(f'GRU: {gru_size}, conv layers: {n_layers}')
    ax[row, column].legend(loc=4)
    
# fig.savefig(f'./plots/gru_size_conv_layer.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
for i in range(4):
    for index, df_row in df.query('conv_layers==@i').sort_values(by='GRU_size').iterrows():
        somma = [x.history['val_acc'] for x in df_row.fit_outs]
        line, = ax[i].plot(np.mean(somma, 0), label=f'GRU:{int(df_row.GRU_size)}')
        ax[i].fill_between(range(np.mean(somma, 0).shape[0]),np.mean(somma, 0)-np.std(somma, 0), np.mean(somma, 0)+np.std(somma, 0),
                        color=line.get_color(), alpha=0.1)
        ax[i].set_title(f'Conv_layers: {i}')
        ax[i].legend(loc=4)
        
# fig.savefig(f'./plots/conv_layer_number.png', bbox_inches='tight')
